# %%
import torch
from IPython.display import Image, clear_output  # to display images
from utils.google_utils import gdrive_download  # to download models/datasets

clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.6.0 _CudaDeviceProperties(name='GeForce GTX 1080 Ti', major=6, minor=1, total_memory=11175MB, multi_processor_count=28)

# %%
# !python train.py --img 1280 --batch 2 --epochs 120 --data soccer.yaml --cfg yolov5x.yaml --cache --weights /home/asad/od/yolov5/weights/yolov5x.pt
# Out:
# Using CUDA device0 _CudaDeviceProperties(name='GeForce GTX 1080 Ti', total_memory=11175MB)
#
# Namespace(adam=False, batch_size=2, bucket='', cache_images=True, cfg='./models/yolov5x.yaml', data='./data/soccer.yaml', device='', epochs=120, evolve=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[1280, 1280], local_rank=-1, logdir='runs/', multi_scale=False, name='', noautoanchor=False, nosave=False, notest=False, rect=False, resume=False, single_cls=False, sync_bn=False, total_batch_size=2, weights='/home/asad/od/yolov5/weights/yolov5x.pt', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/", view at http://localhost:6006/
# Hyperparameters {'lr0': 0.01, 'lrf': 0.2, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'warmup_bias_lr': 0.1, 'giou': 0.05, 'cls': 0.5, 'cls_pw': 1.0, 'obj': 1.0, 'obj_pw': 1.0, 'iou_t': 0.2, 'anchor_t': 4.0, 'fl_gamma': 0.0, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'mosaic': 1.0, 'mixup': 0.0}
# Overriding model.yaml nc=1 with nc=4
#
#                  from  n    params  module                                  arguments
#   0                -1  1      8800  models.common.Focus                     [3, 80, 3]
#   1                -1  1    115520  models.common.Conv                      [80, 160, 3, 2]
#   2                -1  1    315680  models.common.BottleneckCSP             [160, 160, 4]
#   3                -1  1    461440  models.common.Conv                      [160, 320, 3, 2]
#   4                -1  1   3311680  models.common.BottleneckCSP             [320, 320, 12]
#   5                -1  1   1844480  models.common.Conv                      [320, 640, 3, 2]
#   6                -1  1  13228160  models.common.BottleneckCSP             [640, 640, 12]
#   7                -1  1   7375360  models.common.Conv                      [640, 1280, 3, 2]
#   8                -1  1   4099840  models.common.SPP                       [1280, 1280, [5, 9, 13]]
#   9                -1  1  20087040  models.common.BottleneckCSP             [1280, 1280, 4, False]
#  10                -1  1    820480  models.common.Conv                      [1280, 640, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1   5435520  models.common.BottleneckCSP             [1280, 640, 4, False]
#  14                -1  1    205440  models.common.Conv                      [640, 320, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1   1360960  models.common.BottleneckCSP             [640, 320, 4, False]
#  18                -1  1    922240  models.common.Conv                      [320, 320, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1   5025920  models.common.BottleneckCSP             [640, 640, 4, False]
#  21                -1  1   3687680  models.common.Conv                      [640, 640, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1  20087040  models.common.BottleneckCSP             [1280, 1280, 4, False]
#  24      [17, 20, 23]  1     60561  models.yolo.Detect                      [4, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [320, 640, 1280]]
# Model Summary: 407 layers, 8.84538e+07 parameters, 8.84538e+07 gradients, 220.1 GFLOPS
#
# Transferred 794/802 items from /home/asad/od/yolov5/weights/yolov5x.pt
# Optimizer groups: 134 .bias, 142 conv.weight, 131 other
# Scanning images: 100%|████████████████████████| 200/200 [00:03<00:00, 54.60it/s]
# Scanning labels /media/asad/adas_cv_2/caffe/football.cache (200 found, 0 missing, 0 empty, 0 duplicate, for 200 images): 200it [00:00, 9608.06it/s]
# Caching images (0.6GB): 100%|█████████████████| 200/200 [00:02<00:00, 69.88it/s]
# Scanning labels /media/asad/adas_cv_2/caffe/football.cache (200 found, 0 missing, 0 empty, 0 duplicate, for 200 images): 200it [00:00, 4911.19it/s]
# Caching images (0.6GB): 100%|█████████████████| 200/200 [00:02<00:00, 68.85it/s]
#
# Analyzing anchors... anchors/target = 5.00, Best Possible Recall (BPR) = 0.9900
# Image sizes 1280 train, 1280 test
# Using 2 dataloader workers
# Logging results to runs/exp8
# Starting training for 120 epochs...
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      0/119     8.07G   0.09865   0.04664   0.04404    0.1893        39      1280
#                Class      Images     Targets           P           R      mAP@.5
#                  all         200    1.75e+03           0           0       0.015     0.00396
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      1/119     7.85G   0.07669     0.049   0.04095    0.1666        38      1280
#                Class      Images     Targets           P           R      mAP@.5
#                  all         200    1.75e+03       0.131     0.00499       0.186      0.0566
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      2/119     7.85G   0.07548   0.04114   0.03758    0.1542        44      1280
#                Class      Images     Targets           P           R      mAP@.5
#                  all         200    1.75e+03       0.173       0.271       0.192      0.0438
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      3/119     7.85G   0.07025   0.03429   0.03488    0.1394        49      1280
#                Class      Images     Targets           P           R      mAP@.5
#                  all         200    1.75e+03       0.205       0.127       0.166      0.0521
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      4/119     7.85G    0.0647   0.02924   0.03282    0.1268        35      1280
#                Class      Images     Targets           P           R      mAP@.5
#                  all         200    1.75e+03       0.101       0.502       0.194      0.0894
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      5/119     7.85G   0.06599   0.02619   0.03146    0.1236        44      1280
#                Class      Images     Targets           P           R      mAP@.5
#                  all         200    1.75e+03       0.175       0.524        0.25      0.0762
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      6/119     7.85G   0.07406   0.02344    0.0308    0.1283        31      1280
#                Class      Images     Targets           P           R      mAP@.5
#                  all         200    1.75e+03       0.132       0.521       0.238      0.0806
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      7/119     7.85G   0.07784   0.02186   0.02998    0.1297        43      1280
#                Class      Images     Targets           P           R      mAP@.5
#                  all         200    1.75e+03       0.174       0.574       0.265       0.076
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      8/119     7.85G   0.07718   0.02057    0.0294    0.1272        45      1280
#                Class      Images     Targets           P           R      mAP@.5
#                  all         200    1.75e+03       0.268       0.581       0.399       0.133
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      9/119     7.85G   0.07135   0.02091   0.02624    0.1185        23      1280
#                Class      Images     Targets           P           R      mAP@.5
#                  all         200    1.75e+03       0.146       0.721       0.504       0.159
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     10/119     7.85G   0.06699   0.01977   0.02226     0.109        12      1280
#                Class      Images     Targets           P           R      mAP@.5
#                  all         200    1.75e+03       0.184       0.726       0.535       0.181
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     11/119     7.85G   0.06931   0.02028   0.01948    0.1091        57      1280
#                Class      Images     Targets           P           R      mAP@.5
#                  all         200    1.75e+03       0.408       0.733       0.596       0.214
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     12/119     7.85G   0.06651   0.01889   0.01657     0.102        19      1280
#                Class      Images     Targets           P           R      mAP@.5
#                  all         200    1.75e+03       0.264        0.79       0.552       0.179
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     13/119     7.85G   0.05835   0.01899   0.01722   0.09456        30      1280
#                Class      Images     Targets           P           R      mAP@.5
#                  all         200    1.75e+03       0.231       0.827       0.685       0.279
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     14/119     7.85G   0.05752   0.01829   0.01597   0.09178        16      1280
#                Class      Images     Targets           P           R      mAP@.5
#                  all         200    1.75e+03       0.293       0.853       0.686       0.251
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     15/119     7.85G   0.05522   0.01967   0.01384   0.08873        23      1280
#                Class      Images     Targets           P           R      mAP@.5
#                  all         200    1.75e+03       0.405       0.858       0.778       0.317
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     16/119     7.85G   0.05714   0.01897    0.0122    0.0883        33      1280
#                Class      Images     Targets           P           R      mAP@.5
#                  all         200    1.75e+03       0.384       0.965       0.822       0.378
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     17/119     7.85G   0.05151   0.01805   0.01085   0.08041        59      1280
#                Class      Images     Targets           P           R      mAP@.5
#                  all         200    1.75e+03       0.438       0.919       0.799       0.298
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     18/119     7.85G   0.04829   0.01822  0.008813   0.07532        42      1280
#                Class      Images     Targets           P           R      mAP@.5
#                  all         200    1.75e+03       0.418       0.978       0.847       0.378
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     19/119     7.85G    0.0476    0.0182  0.008252   0.07405        59      1280
#                Class      Images     Targets           P           R      mAP@.5
#                  all         200    1.75e+03       0.512       0.948       0.802       0.285
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     20/119     7.85G   0.04575   0.01735  0.006849   0.06995        24      1280
#                Class      Images     Targets           P           R      mAP@.5
#                  all         200    1.75e+03       0.432       0.969       0.834       0.393
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     21/119     7.85G   0.04262   0.01868  0.007323   0.06863        30      1280
#                Class      Images     Targets           P           R      mAP@.5
#                  all         200    1.75e+03       0.497       0.957       0.887       0.409
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     22/119     7.85G   0.04595   0.01845  0.006747   0.07115        39      1280
#                Class      Images     Targets           P           R      mAP@.5
#                  all         200    1.75e+03       0.457       0.977       0.814       0.363
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#